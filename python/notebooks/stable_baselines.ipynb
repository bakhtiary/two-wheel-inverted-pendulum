# %%
import gym

from stable_baselines3 import PPO

env = gym.make("CartPole-v1")

model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=20000)

obs = env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    env.render()
    if done:
      obs = env.reset()

env.close()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | 21.4     |
# | time/              |          |
# |    fps             | 520      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.3        |
# |    ep_rew_mean          | 26.3        |
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008918103 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00326    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.68        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 49.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.6        |
# |    ep_rew_mean          | 34.6        |
# | time/                   |             |
# |    fps                  | 313         |
# |    iterations           | 3           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010177383 |
# |    clip_fraction        | 0.0741      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.665      |
# |    explained_variance   | 0.057       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 36.3        |
# -----------------------------------------

# %%
import gym
import numpy as np

from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

env = gym.make("Pendulum-v1")

# The noise objects for DDPG
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

model = DDPG("MlpPolicy", env, action_noise=action_noise, verbose=1)
model.learn(total_timesteps=1000, log_interval=10)
model.save("ddpg_pendulum")
env = model.get_env()

del model # remove to demonstrate saving and loading

model = DDPG.load("ddpg_pendulum")

obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
import gym
import numpy as np

from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

env = gym.make("LunarLanderContinuous-v2")

# The noise objects for DDPG
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

model = DDPG("MlpPolicy", env, action_noise=action_noise, verbose=1,)
model.learn(total_timesteps=500000, log_interval=10)
model.save("ddpg_pendulum")
env = model.get_env()

del model # remove to demonstrate saving and loading

model = DDPG.load("ddpg_pendulum")

obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | -359     |
# | time/              |          |
# |    episodes        | 10       |
# |    fps             | 79       |
# |    time_elapsed    | 15       |
# |    total timesteps | 1214     |
# | train/             |          |
# |    actor_loss      | 3.06     |
# |    critic_loss     | 28.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1147     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 168      |
# |    ep_rew_mean     | -279     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 72       |
# |    time_elapsed    | 46       |
# |    total timesteps | 3359     |
# | train/             |          |
# |    actor_loss      | -12.6    |
# |    critic_loss     | 31.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3202     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 191      |
# |    ep_rew_mean     | -267     |
# | time/              |          |
# |    episodes        | 30       |
# |    fps             | 74       |
# |    time_elapsed    | 77       |
# |    total timesteps | 5726     |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 33.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5234     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | -231     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 71       |
# |    time_elapsed    | 127      |
# |    total timesteps | 9155     |
# | train/             |          |
# |    actor_loss      | -54.3    |
# |    critic_loss     | 35.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8155     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 238      |
# |    ep_rew_mean     | -211     |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 65       |
# |    time_elapsed    | 181      |
# |    total timesteps | 11887    |
# | train/             |          |
# |    actor_loss      | -85.4    |
# |    critic_loss     | 41.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11790    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 316      |
# |    ep_rew_mean     | -210     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 63       |
# |    time_elapsed    | 299      |
# |    total timesteps | 18972    |
# | train/             |          |
# |    actor_loss      | -133     |
# |    critic_loss     | 54.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 18626    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 310      |
# |    ep_rew_mean     | -197     |
# | time/              |          |
# |    episodes        | 70       |
# |    fps             | 63       |
# |    time_elapsed    | 342      |
# |    total timesteps | 21694    |
# | train/             |          |
# |    actor_loss      | -147     |
# |    critic_loss     | 58.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 21527    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 314      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 62       |
# |    time_elapsed    | 400      |
# |    total timesteps | 25143    |
# | train/             |          |
# |    actor_loss      | -164     |
# |    critic_loss     | 42.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 25046    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 304      |
# |    ep_rew_mean     | -173     |
# | time/              |          |
# |    episodes        | 90       |
# |    fps             | 62       |
# |    time_elapsed    | 435      |
# |    total timesteps | 27363    |
# | train/             |          |
# |    actor_loss      | -171     |
# |    critic_loss     | 61.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27249    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 321      |
# |    ep_rew_mean     | -161     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 62       |
# |    time_elapsed    | 512      |
# |    total timesteps | 32100    |
# | train/             |          |
# |    actor_loss      | -185     |
# |    critic_loss     | 68.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 31888    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 335      |
# |    ep_rew_mean     | -145     |
# | time/              |          |
# |    episodes        | 110      |
# |    fps             | 62       |
# |    time_elapsed    | 552      |
# |    total timesteps | 34702    |
# | train/             |          |
# |    actor_loss      | -198     |
# |    critic_loss     | 78       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 34535    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 358      |
# |    ep_rew_mean     | -139     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 62       |
# |    time_elapsed    | 626      |
# |    total timesteps | 39204    |
# | train/             |          |
# |    actor_loss      | -213     |
# |    critic_loss     | 72.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 39095    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 372      |
# |    ep_rew_mean     | -127     |
# | time/              |          |
# |    episodes        | 130      |
# |    fps             | 62       |
# |    time_elapsed    | 681      |
# |    total timesteps | 42894    |
# | train/             |          |
# |    actor_loss      | -220     |
# |    critic_loss     | 109      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 42337    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 411      |
# |    ep_rew_mean     | -128     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 62       |
# |    time_elapsed    | 798      |
# |    total timesteps | 50255    |
# | train/             |          |
# |    actor_loss      | -228     |
# |    critic_loss     | 94.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 49255    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 429      |
# |    ep_rew_mean     | -130     |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 62       |
# |    time_elapsed    | 872      |
# |    total timesteps | 54794    |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 79.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 53794    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 403      |
# |    ep_rew_mean     | -131     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 61       |
# |    time_elapsed    | 956      |
# |    total timesteps | 59279    |
# | train/             |          |
# |    actor_loss      | -221     |
# |    critic_loss     | 98.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 59051    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 442      |
# |    ep_rew_mean     | -123     |
# | time/              |          |
# |    episodes        | 170      |
# |    fps             | 61       |
# |    time_elapsed    | 1066     |
# |    total timesteps | 65889    |
# | train/             |          |
# |    actor_loss      | -216     |
# |    critic_loss     | 56.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 65706    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 432      |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 61       |
# |    time_elapsed    | 1102     |
# |    total timesteps | 68328    |
# | train/             |          |
# |    actor_loss      | -214     |
# |    critic_loss     | 77.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 68088    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 439      |
# |    ep_rew_mean     | -130     |
# | time/              |          |
# |    episodes        | 190      |
# |    fps             | 61       |
# |    time_elapsed    | 1152     |
# |    total timesteps | 71234    |
# | train/             |          |
# |    actor_loss      | -209     |
# |    critic_loss     | 89.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 71160    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 413      |
# |    ep_rew_mean     | -135     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 61       |
# |    time_elapsed    | 1185     |
# |    total timesteps | 73445    |
# | train/             |          |
# |    actor_loss      | -204     |
# |    critic_loss     | 83.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 73354    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 420      |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    episodes        | 210      |
# |    fps             | 61       |
# |    time_elapsed    | 1238     |
# |    total timesteps | 76663    |
# | train/             |          |
# |    actor_loss      | -195     |
# |    critic_loss     | 99.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 76570    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 400      |
# |    ep_rew_mean     | -116     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 61       |
# |    time_elapsed    | 1278     |
# |    total timesteps | 79188    |
# | train/             |          |
# |    actor_loss      | -190     |
# |    critic_loss     | 67.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79113    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 377      |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    episodes        | 230      |
# |    fps             | 62       |
# |    time_elapsed    | 1299     |
# |    total timesteps | 80642    |
# | train/             |          |
# |    actor_loss      | -188     |
# |    critic_loss     | 98.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80554    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 340      |
# |    ep_rew_mean     | -132     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 62       |
# |    time_elapsed    | 1349     |
# |    total timesteps | 84265    |
# | train/             |          |
# |    actor_loss      | -184     |
# |    critic_loss     | 79       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83741    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 340      |
# |    ep_rew_mean     | -128     |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 62       |
# |    time_elapsed    | 1424     |
# |    total timesteps | 88798    |
# | train/             |          |
# |    actor_loss      | -175     |
# |    critic_loss     | 66.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 88587    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 340      |
# |    ep_rew_mean     | -102     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 62       |
# |    time_elapsed    | 1497     |
# |    total timesteps | 93255    |
# | train/             |          |
# |    actor_loss      | -167     |
# |    critic_loss     | 62.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 93044    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 339      |
# |    ep_rew_mean     | -104     |
# | time/              |          |
# |    episodes        | 270      |
# |    fps             | 62       |
# |    time_elapsed    | 1605     |
# |    total timesteps | 99809    |
# | train/             |          |
# |    actor_loss      | -158     |
# |    critic_loss     | 68.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99732    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 391      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 62       |
# |    time_elapsed    | 1720     |
# |    total timesteps | 107448   |
# | train/             |          |
# |    actor_loss      | -151     |
# |    critic_loss     | 50.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 106448   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 441      |
# |    ep_rew_mean     | -86.6    |
# | time/              |          |
# |    episodes        | 290      |
# |    fps             | 61       |
# |    time_elapsed    | 1861     |
# |    total timesteps | 115292   |
# | train/             |          |
# |    actor_loss      | -138     |
# |    critic_loss     | 42.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 115058   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 478      |
# |    ep_rew_mean     | -83.3    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 61       |
# |    time_elapsed    | 1958     |
# |    total timesteps | 121241   |
# | train/             |          |
# |    actor_loss      | -129     |
# |    critic_loss     | 35.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 120820   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 510      |
# |    ep_rew_mean     | -78.5    |
# | time/              |          |
# |    episodes        | 310      |
# |    fps             | 61       |
# |    time_elapsed    | 2067     |
# |    total timesteps | 127696   |
# | train/             |          |
# |    actor_loss      | -121     |
# |    critic_loss     | 38       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 127441   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 533      |
# |    ep_rew_mean     | -65.7    |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 61       |
# |    time_elapsed    | 2143     |
# |    total timesteps | 132449   |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 37.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 132271   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 555      |
# |    ep_rew_mean     | -37.5    |
# | time/              |          |
# |    episodes        | 330      |
# |    fps             | 62       |
# |    time_elapsed    | 2194     |
# |    total timesteps | 136146   |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 31.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 135626   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 550      |
# |    ep_rew_mean     | -3.6     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 62       |
# |    time_elapsed    | 2245     |
# |    total timesteps | 139270   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 34       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 139018   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 544      |
# |    ep_rew_mean     | 12.4     |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 62       |
# |    time_elapsed    | 2302     |
# |    total timesteps | 143221   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 34.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 142693   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 542      |
# |    ep_rew_mean     | 19.6     |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 62       |
# |    time_elapsed    | 2368     |
# |    total timesteps | 147431   |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 35.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 146974   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 513      |
# |    ep_rew_mean     | 39.8     |
# | time/              |          |
# |    episodes        | 370      |
# |    fps             | 62       |
# |    time_elapsed    | 2429     |
# |    total timesteps | 151130   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 35.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 150872   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 470      |
# |    ep_rew_mean     | 70.6     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 62       |
# |    time_elapsed    | 2478     |
# |    total timesteps | 154406   |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 24.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 154157   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 425      |
# |    ep_rew_mean     | 88.2     |
# | time/              |          |
# |    episodes        | 390      |
# |    fps             | 62       |
# |    time_elapsed    | 2527     |
# |    total timesteps | 157838   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 33.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 157349   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 402      |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 62       |
# |    time_elapsed    | 2584     |
# |    total timesteps | 161416   |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 30       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 161165   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 369      |
# |    ep_rew_mean     | 139      |
# | time/              |          |
# |    episodes        | 410      |
# |    fps             | 62       |
# |    time_elapsed    | 2633     |
# |    total timesteps | 164633   |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 31.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 164419   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 341      |
# |    ep_rew_mean     | 153      |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 62       |
# |    time_elapsed    | 2659     |
# |    total timesteps | 166534   |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 21.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 166221   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 340      |
# |    ep_rew_mean     | 153      |
# | time/              |          |
# |    episodes        | 430      |
# |    fps             | 62       |
# |    time_elapsed    | 2715     |
# |    total timesteps | 170195   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 24.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 169860   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 333      |
# |    ep_rew_mean     | 159      |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 62       |
# |    time_elapsed    | 2753     |
# |    total timesteps | 172609   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 29.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 172464   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 330      |
# |    ep_rew_mean     | 176      |
# | time/              |          |
# |    episodes        | 450      |
# |    fps             | 62       |
# |    time_elapsed    | 2805     |
# |    total timesteps | 176200   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 27.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175848   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 315      |
# |    ep_rew_mean     | 183      |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 62       |
# |    time_elapsed    | 2846     |
# |    total timesteps | 178910   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 26.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 178605   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 308      |
# |    ep_rew_mean     | 192      |
# | time/              |          |
# |    episodes        | 470      |
# |    fps             | 62       |
# |    time_elapsed    | 2892     |
# |    total timesteps | 181965   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 19.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 181681   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 310      |
# |    ep_rew_mean     | 190      |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 62       |
# |    time_elapsed    | 2945     |
# |    total timesteps | 185364   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 30.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 185156   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 193      |
# | time/              |          |
# |    episodes        | 490      |
# |    fps             | 62       |
# |    time_elapsed    | 2985     |
# |    total timesteps | 187930   |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 25.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 187832   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 285      |
# |    ep_rew_mean     | 194      |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 62       |
# |    time_elapsed    | 3015     |
# |    total timesteps | 189905   |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 26       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 189837   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 275      |
# |    ep_rew_mean     | 187      |
# | time/              |          |
# |    episodes        | 510      |
# |    fps             | 63       |
# |    time_elapsed    | 3045     |
# |    total timesteps | 192091   |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 30.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 191876   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 278      |
# |    ep_rew_mean     | 186      |
# | time/              |          |
# |    episodes        | 520      |
# |    fps             | 63       |
# |    time_elapsed    | 3079     |
# |    total timesteps | 194363   |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 30.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 194140   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 260      |
# |    ep_rew_mean     | 189      |
# | time/              |          |
# |    episodes        | 530      |
# |    fps             | 63       |
# |    time_elapsed    | 3105     |
# |    total timesteps | 196217   |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 42.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 195866   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 256      |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 540      |
# |    fps             | 63       |
# |    time_elapsed    | 3136     |
# |    total timesteps | 198219   |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 28.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198017   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 238      |
# |    ep_rew_mean     | 197      |
# | time/              |          |
# |    episodes        | 550      |
# |    fps             | 63       |
# |    time_elapsed    | 3162     |
# |    total timesteps | 200041   |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 29.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199808   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 240      |
# |    ep_rew_mean     | 205      |
# | time/              |          |
# |    episodes        | 560      |
# |    fps             | 63       |
# |    time_elapsed    | 3206     |
# |    total timesteps | 202924   |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 27       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 202694   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 229      |
# |    ep_rew_mean     | 207      |
# | time/              |          |
# |    episodes        | 570      |
# |    fps             | 63       |
# |    time_elapsed    | 3235     |
# |    total timesteps | 204880   |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 36.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 204714   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | 212      |
# | time/              |          |
# |    episodes        | 580      |
# |    fps             | 63       |
# |    time_elapsed    | 3271     |
# |    total timesteps | 207955   |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 34.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 206955   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 226      |
# |    ep_rew_mean     | 216      |
# | time/              |          |
# |    episodes        | 590      |
# |    fps             | 63       |
# |    time_elapsed    | 3319     |
# |    total timesteps | 210533   |
# | train/             |          |
# |    actor_loss      | -119     |
# |    critic_loss     | 36.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 210316   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 236      |
# |    ep_rew_mean     | 222      |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 63       |
# |    time_elapsed    | 3366     |
# |    total timesteps | 213533   |
# | train/             |          |
# |    actor_loss      | -119     |
# |    critic_loss     | 27.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 213372   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 244      |
# |    ep_rew_mean     | 219      |
# | time/              |          |
# |    episodes        | 610      |
# |    fps             | 63       |
# |    time_elapsed    | 3411     |
# |    total timesteps | 216501   |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 25       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 216268   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 251      |
# |    ep_rew_mean     | 225      |
# | time/              |          |
# |    episodes        | 620      |
# |    fps             | 63       |
# |    time_elapsed    | 3456     |
# |    total timesteps | 219423   |
# | train/             |          |
# |    actor_loss      | -119     |
# |    critic_loss     | 30.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 219229   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 255      |
# |    ep_rew_mean     | 232      |
# | time/              |          |
# |    episodes        | 630      |
# |    fps             | 63       |
# |    time_elapsed    | 3489     |
# |    total timesteps | 221685   |
# | train/             |          |
# |    actor_loss      | -119     |
# |    critic_loss     | 30.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 221508   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 259      |
# |    ep_rew_mean     | 232      |
# | time/              |          |
# |    episodes        | 640      |
# |    fps             | 63       |
# |    time_elapsed    | 3525     |
# |    total timesteps | 224163   |
# | train/             |          |
# |    actor_loss      | -119     |
# |    critic_loss     | 28.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 223904   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 271      |
# |    ep_rew_mean     | 232      |
# | time/              |          |
# |    episodes        | 650      |
# |    fps             | 63       |
# |    time_elapsed    | 3566     |
# |    total timesteps | 227102   |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 22.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 226608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 279      |
# |    ep_rew_mean     | 231      |
# | time/              |          |
# |    episodes        | 660      |
# |    fps             | 63       |
# |    time_elapsed    | 3626     |
# |    total timesteps | 230794   |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 39.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 230611   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 291      |
# |    ep_rew_mean     | 227      |
# | time/              |          |
# |    episodes        | 670      |
# |    fps             | 63       |
# |    time_elapsed    | 3674     |
# |    total timesteps | 234010   |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 26.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 233818   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 295      |
# |    ep_rew_mean     | 219      |
# | time/              |          |
# |    episodes        | 680      |
# |    fps             | 63       |
# |    time_elapsed    | 3726     |
# |    total timesteps | 237481   |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 30.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 237294   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 292      |
# |    ep_rew_mean     | 221      |
# | time/              |          |
# |    episodes        | 690      |
# |    fps             | 63       |
# |    time_elapsed    | 3758     |
# |    total timesteps | 239702   |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 34.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 239450   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 299      |
# |    ep_rew_mean     | 205      |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 63       |
# |    time_elapsed    | 3805     |
# |    total timesteps | 243428   |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 32.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 242428   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 294      |
# |    ep_rew_mean     | 201      |
# | time/              |          |
# |    episodes        | 710      |
# |    fps             | 63       |
# |    time_elapsed    | 3852     |
# |    total timesteps | 245874   |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 22       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 245684   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 324      |
# |    ep_rew_mean     | 194      |
# | time/              |          |
# |    episodes        | 720      |
# |    fps             | 64       |
# |    time_elapsed    | 3934     |
# |    total timesteps | 251848   |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 27.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 250848   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 327      |
# |    ep_rew_mean     | 196      |
# | time/              |          |
# |    episodes        | 730      |
# |    fps             | 63       |
# |    time_elapsed    | 3982     |
# |    total timesteps | 254404   |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 29       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 254205   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 338      |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 740      |
# |    fps             | 63       |
# |    time_elapsed    | 4037     |
# |    total timesteps | 257957   |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 19.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 257735   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 341      |
# |    ep_rew_mean     | 190      |
# | time/              |          |
# |    episodes        | 750      |
# |    fps             | 63       |
# |    time_elapsed    | 4087     |
# |    total timesteps | 261217   |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 31.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 261044   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 342      |
# |    ep_rew_mean     | 178      |
# | time/              |          |
# |    episodes        | 760      |
# |    fps             | 63       |
# |    time_elapsed    | 4147     |
# |    total timesteps | 265027   |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 21.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 264709   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 340      |
# |    ep_rew_mean     | 175      |
# | time/              |          |
# |    episodes        | 770      |
# |    fps             | 63       |
# |    time_elapsed    | 4189     |
# |    total timesteps | 268027   |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 30.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 267488   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 344      |
# |    ep_rew_mean     | 177      |
# | time/              |          |
# |    episodes        | 780      |
# |    fps             | 64       |
# |    time_elapsed    | 4242     |
# |    total timesteps | 271848   |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 20.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 270848   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 343      |
# |    ep_rew_mean     | 169      |
# | time/              |          |
# |    episodes        | 790      |
# |    fps             | 63       |
# |    time_elapsed    | 4284     |
# |    total timesteps | 274023   |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 20       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 273732   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 336      |
# |    ep_rew_mean     | 177      |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 63       |
# |    time_elapsed    | 4330     |
# |    total timesteps | 276996   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 29       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 276642   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 345      |
# |    ep_rew_mean     | 179      |
# | time/              |          |
# |    episodes        | 810      |
# |    fps             | 64       |
# |    time_elapsed    | 4374     |
# |    total timesteps | 280398   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 26       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 279565   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 308      |
# |    ep_rew_mean     | 182      |
# | time/              |          |
# |    episodes        | 820      |
# |    fps             | 63       |
# |    time_elapsed    | 4415     |
# |    total timesteps | 282612   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 21.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 282436   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 314      |
# |    ep_rew_mean     | 179      |
# | time/              |          |
# |    episodes        | 830      |
# |    fps             | 64       |
# |    time_elapsed    | 4463     |
# |    total timesteps | 285764   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 24.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 285563   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 310      |
# |    ep_rew_mean     | 189      |
# | time/              |          |
# |    episodes        | 840      |
# |    fps             | 64       |
# |    time_elapsed    | 4500     |
# |    total timesteps | 288949   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 28.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 287949   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 313      |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 850      |
# |    fps             | 64       |
# |    time_elapsed    | 4563     |
# |    total timesteps | 292493   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 20.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 292241   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 322      |
# |    ep_rew_mean     | 199      |
# | time/              |          |
# |    episodes        | 860      |
# |    fps             | 64       |
# |    time_elapsed    | 4630     |
# |    total timesteps | 297199   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 25.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 296623   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 319      |
# |    ep_rew_mean     | 199      |
# | time/              |          |
# |    episodes        | 870      |
# |    fps             | 64       |
# |    time_elapsed    | 4674     |
# |    total timesteps | 299905   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 21.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 299657   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 310      |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 880      |
# |    fps             | 64       |
# |    time_elapsed    | 4720     |
# |    total timesteps | 302844   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 29.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 302712   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 325      |
# |    ep_rew_mean     | 189      |
# | time/              |          |
# |    episodes        | 890      |
# |    fps             | 64       |
# |    time_elapsed    | 4778     |
# |    total timesteps | 306513   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 33       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 306389   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 327      |
# |    ep_rew_mean     | 196      |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 64       |
# |    time_elapsed    | 4826     |
# |    total timesteps | 309739   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 26.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 309559   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 316      |
# |    ep_rew_mean     | 209      |
# | time/              |          |
# |    episodes        | 910      |
# |    fps             | 64       |
# |    time_elapsed    | 4859     |
# |    total timesteps | 311986   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 21.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 311784   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 340      |
# |    ep_rew_mean     | 210      |
# | time/              |          |
# |    episodes        | 920      |
# |    fps             | 64       |
# |    time_elapsed    | 4931     |
# |    total timesteps | 316590   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 31.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 316360   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 334      |
# |    ep_rew_mean     | 209      |
# | time/              |          |
# |    episodes        | 930      |
# |    fps             | 64       |
# |    time_elapsed    | 4967     |
# |    total timesteps | 319214   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 27.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 318755   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 334      |
# |    ep_rew_mean     | 208      |
# | time/              |          |
# |    episodes        | 940      |
# |    fps             | 64       |
# |    time_elapsed    | 5016     |
# |    total timesteps | 322376   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 17.2     |
# |    learning_rate   | 0.001    |
# ...
# |    total timesteps | 439939   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 17.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 439775   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 223      |
# |    ep_rew_mean     | 245      |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 65       |
# |    time_elapsed    | 6731     |
# |    total timesteps | 442240   |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 23.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 442064   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 221      |
# |    ep_rew_mean     | 242      |
# | time/              |          |
# |    episodes        | 1410     |
# |    fps             | 65       |
# |    time_elapsed    | 6762     |
# |    total timesteps | 444576   |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 28.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 444396   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 232      |
# |    ep_rew_mean     | 237      |
# | time/              |          |
# |    episodes        | 1420     |
# |    fps             | 65       |
# |    time_elapsed    | 6804     |
# |    total timesteps | 447705   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 23.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 447471   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 239      |
# |    ep_rew_mean     | 236      |
# | time/              |          |
# |    episodes        | 1430     |
# |    fps             | 65       |
# |    time_elapsed    | 6839     |
# |    total timesteps | 450357   |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 25.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 450071   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 239      |
# |    ep_rew_mean     | 237      |
# | time/              |          |
# |    episodes        | 1440     |
# |    fps             | 65       |
# |    time_elapsed    | 6868     |
# |    total timesteps | 452477   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 24.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 452310   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 239      |
# |    ep_rew_mean     | 240      |
# | time/              |          |
# |    episodes        | 1450     |
# |    fps             | 65       |
# |    time_elapsed    | 6902     |
# |    total timesteps | 455121   |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 16.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 454822   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 232      |
# |    ep_rew_mean     | 240      |
# | time/              |          |
# |    episodes        | 1460     |
# |    fps             | 65       |
# |    time_elapsed    | 6929     |
# |    total timesteps | 457105   |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 15.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 456874   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 250      |
# |    ep_rew_mean     | 236      |
# | time/              |          |
# |    episodes        | 1470     |
# |    fps             | 66       |
# |    time_elapsed    | 6983     |
# |    total timesteps | 460993   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 24.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 460819   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 257      |
# |    ep_rew_mean     | 235      |
# | time/              |          |
# |    episodes        | 1480     |
# |    fps             | 66       |
# |    time_elapsed    | 7017     |
# |    total timesteps | 463774   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 12.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 463279   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 266      |
# |    ep_rew_mean     | 240      |
# | time/              |          |
# |    episodes        | 1490     |
# |    fps             | 66       |
# |    time_elapsed    | 7058     |
# |    total timesteps | 466572   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 20.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 466421   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 287      |
# |    ep_rew_mean     | 243      |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 66       |
# |    time_elapsed    | 7108     |
# |    total timesteps | 470980   |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 17.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 469980   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 291      |
# |    ep_rew_mean     | 246      |
# | time/              |          |
# |    episodes        | 1510     |
# |    fps             | 66       |
# |    time_elapsed    | 7154     |
# |    total timesteps | 473638   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 29.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 473441   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 288      |
# |    ep_rew_mean     | 246      |
# | time/              |          |
# |    episodes        | 1520     |
# |    fps             | 66       |
# |    time_elapsed    | 7192     |
# |    total timesteps | 476492   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 24.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 476302   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 282      |
# |    ep_rew_mean     | 244      |
# | time/              |          |
# |    episodes        | 1530     |
# |    fps             | 66       |
# |    time_elapsed    | 7218     |
# |    total timesteps | 478526   |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 23.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 478301   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 288      |
# |    ep_rew_mean     | 240      |
# | time/              |          |
# |    episodes        | 1540     |
# |    fps             | 66       |
# |    time_elapsed    | 7255     |
# |    total timesteps | 481304   |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 14       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 481124   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 283      |
# |    ep_rew_mean     | 236      |
# | time/              |          |
# |    episodes        | 1550     |
# |    fps             | 66       |
# |    time_elapsed    | 7282     |
# |    total timesteps | 483448   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 21.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 483106   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 287      |
# |    ep_rew_mean     | 236      |
# | time/              |          |
# |    episodes        | 1560     |
# |    fps             | 66       |
# |    time_elapsed    | 7314     |
# |    total timesteps | 485760   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 14.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 485534   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 267      |
# |    ep_rew_mean     | 244      |
# | time/              |          |
# |    episodes        | 1570     |
# |    fps             | 66       |
# |    time_elapsed    | 7339     |
# |    total timesteps | 487717   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 20.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 487510   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 271      |
# |    ep_rew_mean     | 242      |
# | time/              |          |
# |    episodes        | 1580     |
# |    fps             | 66       |
# |    time_elapsed    | 7382     |
# |    total timesteps | 490865   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 24.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 490695   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 270      |
# |    ep_rew_mean     | 244      |
# | time/              |          |
# |    episodes        | 1590     |
# |    fps             | 66       |
# |    time_elapsed    | 7415     |
# |    total timesteps | 493550   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 24.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 493199   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 247      |
# |    ep_rew_mean     | 249      |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 66       |
# |    time_elapsed    | 7445     |
# |    total timesteps | 495721   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 23.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 495441   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 250      |
# |    ep_rew_mean     | 253      |
# | time/              |          |
# |    episodes        | 1610     |
# |    fps             | 66       |
# |    time_elapsed    | 7486     |
# |    total timesteps | 498667   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 19.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498456   |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_60539/1010679554.py in <module>
#      22 obs = env.reset()
#      23 while True:
# ---> 24     action, _states = model.predict(obs)
#      25     obs, rewards, dones, info = env.step(action)
#      26     env.render()
#
# ~/.local/share/virtualenvs/python-rQ1OrFAJ/lib/python3.9/site-packages/stable_baselines3/common/base_class.py in predict(self, observation, state, mask, deterministic)
#     538             (used in recurrent policies)
#     539         """
# --> 540         return self.policy.predict(observation, state, mask, deterministic)
#     541
#     542     def set_random_seed(self, seed: Optional[int] = None) -> None:
#
# ~/.local/share/virtualenvs/python-rQ1OrFAJ/lib/python3.9/site-packages/stable_baselines3/common/policies.py in predict(self, observation, state, mask, deterministic)
#     324
#     325         with th.no_grad():
# --> 326             actions = self._predict(observation, deterministic=deterministic)
#     327         # Convert to numpy
#     328         actions = actions.cpu().numpy()
#
# ~/.local/share/virtualenvs/python-rQ1OrFAJ/lib/python3.9/site-packages/stable_baselines3/td3/policies.py in _predict(self, observation, deterministic)
#     228         # Note: the deterministic deterministic parameter is ignored in the case of TD3.
#     229         #   Predictions are always deterministic.
# --> 230         return self.actor(observation)
#     231
#     232     def set_training_mode(self, mode: bool) -> None:
#
# ~/.local/share/virtualenvs/python-rQ1OrFAJ/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/share/virtualenvs/python-rQ1OrFAJ/lib/python3.9/site-packages/stable_baselines3/td3/policies.py in forward(self, obs)
#      76         # assert deterministic, 'The TD3 actor only outputs deterministic actions'
#      77         features = self.extract_features(obs)
# ---> 78         return self.mu(features)
#      79
#      80     def _predict(self, observation: th.Tensor, deterministic: bool = False) -> th.Tensor:
#
# ~/.local/share/virtualenvs/python-rQ1OrFAJ/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/share/virtualenvs/python-rQ1OrFAJ/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# ~/.local/share/virtualenvs/python-rQ1OrFAJ/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/share/virtualenvs/python-rQ1OrFAJ/lib/python3.9/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      94
#      95     def forward(self, input: Tensor) -> Tensor:
# ---> 96         return F.linear(input, self.weight, self.bias)
#      97
#      98     def extra_repr(self) -> str:
#
# ~/.local/share/virtualenvs/python-rQ1OrFAJ/lib/python3.9/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1845     if has_torch_function_variadic(input, weight):
#    1846         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1847     return torch._C._nn.linear(input, weight, bias)
#    1848
#    1849
#
# KeyboardInterrupt:

# %%
import gym
import numpy as np

from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from rl_training.two_wheel_robot import TwoWheelRobot

env = TwoWheelRobot()

# %%
while True:
  env.reset()
  env.render()
  for i in range(100):
    env.step((0,0))
    env.render()
# Out:
# Creating window glfw

# %%
import tensorflow

# %%
tensorflow.
